# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x=np.array([[5,2],[7,4],[11,9],[15,12],[19,17]])
y=np.array([7,3,5,19,6])
model=LinearRegression().fit(x,y)
ypred=model.predict(x)
print(model.score(x,y))
print(model.score(x,ypred))
plt.plot(x,ypred)
# Out:
# 0.6313446969696973
# 1.0
# [<matplotlib.lines.Line2D at 0x20aa36dd520>,
#  <matplotlib.lines.Line2D at 0x20aa36dd550>]

# %%
plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x20aa37e0910>,
#  <matplotlib.lines.Line2D at 0x20aa37e0940>]

# %%
print(ypred)
# Out:
# [ 5.84848485  7.75757576  1.68181818 15.39393939  9.31818182]

# %%
xnew=np.random.rand(10)*10
xnew_=xnew.reshape(-1,2)
ynew_=model.predict(xnew_)

print(ynew_)
plt.plot(xnew_,ynew_)
# Out:
# [ -6.2032136  -38.9898367  -73.65272203   7.61194992 -89.24150689]
# [<matplotlib.lines.Line2D at 0x20aa3864130>,
#  <matplotlib.lines.Line2D at 0x20aa3864160>]
