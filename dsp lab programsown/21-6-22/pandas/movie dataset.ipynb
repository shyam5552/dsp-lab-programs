# %%
import pandas as pd
df=pd.read_csv("bollywood.csv")
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
import numpy as np

# %%
dg=df["MovieName"]
dg.count()
# Out:
# 149

# %%
dh=df[["Genre"]].value_counts()
dh
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\T8381~1.SHY\AppData\Local\Temp/ipykernel_8016/644454266.py in <module>
# ----> 1 dh=df[["Genre,"]].value_counts()
#       2 dh
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
df[["Genre"]].value_counts().max()
# Out:
# 36

# %%
df.loc[df["BoxOfficeCollection"]>=86]
# Out:
#      SlNo Release Date                  MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                   2 States          LW    Romance
# 12     13    27-Jun-14                 Ek Villain          HS    Romance
# 14     15     8-Aug-14              Entertainment           N     Comedy
# 16     17    25-Jan-13                     Race 2          LW  Thriller
# 25     26     8-Feb-13                 Special 26           N     Drama
# 26     27    24-Oct-14             Happy New Year          LW     Drama
# 36     37     6-Jun-14                    Holiday          HS     Action
# 37     38    11-Jul-14  Humpty Sharma Ki Dulhania           N    Romance
# 41     42    24-Jan-14                     Jai Ho           N     Action
# 43     44    25-Jul-14                       Kick           N     Action
# 54     55    29-Mar-13                 Himmatwala           N     Action
# 58     59     5-Sep-14                   Mary Kom           N     Drama
# ...

# %%
df.groupby(["ReleaseTime"]).groups
# Out:
# {'FS': [23, 31, 40, 62, 92, 106, 115, 116, 119, 121, 122, 125, 126, 127, 128, 142, 143], 'HS': [5, 12, 17, 19, 29, 32, 36, 39, 48, 49, 55, 60, 67, 85, 89, 99, 133, 148], 'LW': [0, 8, 16, 26, 52, 59, 61, 78, 80, 83, 96, 114, 130, 131, 132], 'N': [1, 2, 3, 4, 6, 7, 9, 10, 11, 13, 14, 15, 18, 20, 21, 22, 24, 25, 27, 28, 30, 33, 34, 35, 37, 38, 41, 42, 43, 44, 45, 46, 47, 50, 51, 53, 54, 56, 57, 58, 63, 64, 65, 66, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 79, 81, 82, 84, 86, 87, 88, 90, 91, 93, 94, 95, 97, 98, 100, 101, 102, 103, 104, 105, 107, 108, 109, 110, 111, 112, 113, 117, 118, 120, 123, 124, 129, 134, 135, 136, 137, 138, 139, 140, 141, 144, 145, 146, 147]}

# %%
x=df["Release Date"].value_counts()

# %%
y=pd.Series(x)
y
# Out:
# 9-May-14     5
# 18-Jul-14    3
# 15-Mar-13    3
# 28-Mar-14    3
# 18-Jan-13    3
#             ..
# 19-Apr-13    1
# 5-Sep-14     1
# 5-Apr-13     1
# 22-Aug-14    1
# 10-May-13    1
# Name: Release Date, Length: 102, dtype: int64
