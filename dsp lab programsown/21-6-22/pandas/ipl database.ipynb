# %%
import pandas as pd
df=pd.read_csv("IPL IMB381IPL2013.csv")
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
list(df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df[["PLAYER NAME","COUNTRY"]].head().transpose()
# Out:
#                        0             1            2          3             4
# PLAYER NAME  Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# COUNTRY               SA           BAN          IND        IND           IND

# %%
df.shape
# Out:
# (130, 26)

# %%
#slicing operations
df[["PLAYER NAME","BASE PRICE"]][5:10].sort_values(["BASE PRICE"])
# Out:
#      PLAYER NAME  BASE PRICE
# 5     Bailey, GJ       50000
# 6      Balaji, L      100000
# 7  Bollinger, DE      200000
# 8       Botha, J      200000
# 9    Boucher, MV      200000

# %%
df.iloc[0:5,1:5]
# Out:
#     PLAYER NAME  AGE COUNTRY  TEAM
# 0   Abdulla, YA    2      SA  KXIP
# 1  Abdur Razzak    2     BAN   RCB
# 2   Agarkar, AB    2     IND   KKR
# 3     Ashwin, R    1     IND   CSK
# 4  Badrinath, S    2     IND   CSK

# %%
#value counts
df.TEAM.value_counts()
# Out:
# CSK      14
# RCB+     12
# KKR+     12
# DD+      10
# DC+      10
# RR+       9
# RCB       9
# DC        7
# KXIP+     7
# MI        6
# DD        6
# MI+       6
# RR        6
# CSK+      5
# KKR       5
# KXIP      5
# KXI+      1
# Name: TEAM, dtype: int64

# %%
pd.crosstab(df["AGE"],df["PLAYING ROLE"])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
#sorting df by columns
x=df[["PLAYER NAME","SOLD PRICE"]].sort_values("SOLD PRICE",ascending=True)[0:5]
x
# Out:
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000

# %%
#creating new column
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
#grouping and arranging
y=df.groupby("AGE")["SOLD PRICE"].mean()
y
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
y=df.groupby("AGE")["SOLD PRICE"].mean().reset_index()
y
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
#ranaming cloumna names
#df.rename(columns={},inplace=true)

# %%
df[df["SIXERS"]>90][["PLAYER NAME","SIXERS"]]
# Out:
#    PLAYER NAME  SIXERS
# 26   Gayle, CH     129
# 88   Raina, SK      97

# %%
df[df["SIXERS"]>90]
# Out:
#     Sl.NO. PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 26      27   Gayle, CH    2      WI  KKR+   Allrounder    6373      72
# 88      89   Raina, SK    1     IND   CSK      Batsman     710      13
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 26        8087     83.95  ...  161.79     129     606    13   46.62  8.05
# 88        3525     92.71  ...  139.39      97     678    20   33.90  7.05
#
#     SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 26  34.85          2008      250000      800000
# 88  28.90          2008      125000      650000
#
# [2 rows x 26 columns]

# %%
#visualization 
import matplotlib.pyplot as plt
x=df["AGE"]
y=df["SOLD PRICE"]

plt.bar(x,y)


plt.show()
