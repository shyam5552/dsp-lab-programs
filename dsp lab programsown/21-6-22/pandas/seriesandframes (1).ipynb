# %%
import pandas as pd
df={"name":["shyam","shivasai","pavan","ramana","basha"],
   "id":[22,23,24,25,26]}
pd.DataFrame(df)
#creating dataframe
# Out:
#        name  id
# 0     shyam  22
# 1  shivasai  23
# 2     pavan  24
# 3    ramana  25
# 4     basha  26

# %%
#creating sries
import pandas as pd
df=[1,2]
myvar=pd.Series(df)
print(myvar)
print(myvar[0:])
# Out:
# 0    1
# 1    2
# dtype: int64
# 0    1
# 1    2
# dtype: int64

# %%
#user indexing
myvar=pd.Series(df,index=["a","b"])
print(myvar)
# Out:
# a    1
# b    2
# dtype: int64

# %%
#keyvalue object series
en={"d1":20,"d2":30,"d3":40}
myvar=pd.Series(en)
print(myvar)
myv=pd.Series(en,index=["d1","d2"])
print(myv)
# Out:
# d1    20
# d2    30
# d3    40
# dtype: int64
# d1    20
# d2    30
# dtype: int64

# %%
#dataframesoperations
import pandas as pd
data={"calories":[5,6,7],"dureation":[10,20,30]}
df=pd.DataFrame(data)

print(df)
# Out:
#    calories  dureation
# 0         5         10
# 1         6         20
# 2         7         30

# %%
print(df.loc[1])
# Out:
# calories      6
# dureation    20
# Name: 1, dtype: int64

# %%
iu=pd.DataFrame(data,index=["d1","d2","d3"])
print(iu)
# Out:
#     calories  dureation
# d1         5         10
# d2         6         20
# d3         7         30

# %%
import pandas as pd
df=pd.read_csv("1000salesrecords.csv")
df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...
