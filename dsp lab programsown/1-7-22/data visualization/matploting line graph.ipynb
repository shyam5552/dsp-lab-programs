# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,10])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=np.array([3,3,3.05,3.1,3.1])
ypoint=np.array([4,7,5.5,7,4])
plt.plot(xpoint,ypoint,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,1,6,6,1],[1,5,5,1,1],marker="o")
plt.plot([1,6],[1,5],"--")
plt.plot([1,6],[5,1],color="red")
plt.plot([1,3.5,6],[5,10,5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\T8381~1.SHY\AppData\Local\Temp/ipykernel_8048/591342410.py in <module>
#       5 plt.plot([1,6],[5,1],color="red")
#       6 plt.plot([1,3.5,6],[5,10,5])
# ----> 7 plt.xlabel("country")
#       8 plt.ylabel("GDP")
#       9 plt.show()
#
# TypeError: 'str' object is not callable

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("HOME",color="red")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot([1,1,6,6,1],[1,5,5,1,1],marker="o",c="red")
plt.plot([1,3.5,6],[5,10,5],marker="o")
plt.plot([2.5,4.5],[8,8],marker="o")
plt.plot([2,5],[7,7],marker="o")
plt.plot([1.5,5.5],[6,6],marker="o")
plt.plot([2,2],[1,5])
plt.plot([3,3],[1,5])
plt.plot([4,4],[1,5])
plt.plot([5,5],[1,5])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter([1,2,3,4],[1,2,3,4],color="red")
plt.show()

# %%
x=[1972,1982,1992,2002,2012]
y=[100.6,158.61,305.54,394.96,724.79]
plt.xlabel('year')
plt.ylabel('power')
plot(x,y,marker="o",color="red",label="india")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\T8381~1.SHY\AppData\Local\Temp/ipykernel_8048/3454010812.py in <module>
#       1 x=[1972,1982,1992,2002,2012]
#       2 y=[100.6,158.61,305.54,394.96,724.79]
# ----> 3 plt.xlabel('year')
#       4 plt.ylabel('power')
#       5 plot(x,y,marker="o",color="red",label="india")
#
# TypeError: 'str' object is not callable

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("IPL IMB381IPL2013.csv")
y=df.groupby("PLAYING ROLE")["SOLD PRICE"].mean()
print(y,index=y["PLAYING ROLE"])

# %%
x=y["SOLD PRICE"].tolist()
xlabels=y["PLAYING ROLE"]
plt.pie(x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\T8381~1.SHY\AppData\Local\Temp/ipykernel_8048/1549409239.py in <module>
# ----> 1 x=y["SOLD PRICE"].tolist()
#       2 xlabels=y["PLAYING ROLE"]
#       3 plt.pie(x)
#       4 plt.show()
#
# TypeError: list indices must be integers or slices, not str

# %%
plt.plot([1,1],[1,2])
plt.plot([1,2],[1,1])
plt.show()
